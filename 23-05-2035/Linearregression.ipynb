# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Salary%20Data.csv')

# %%
x = data[['Experience Years']].values
y = data['Salary'].values

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)

# %%
numerator = np.sum((x - x_mean) * (y - y_mean))
denominator = np.sum((x - x_mean) ** 2)
m = numerator/denominator

# %%
b = y_mean - m * x_mean

# %%
y_pred = m * x + b

# %%
print("Slope (m)",m)
print("Intercept (b)",b)
print("Predicetd value (y_pred)",y_pred)
# Out:
# Slope (m) -1.5250286313956222e-12
# Intercept (b) 74743.62500000001
# Predicetd value (y_pred) [[74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]
#  [74743.625]]

# %%
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression - Salary vs Experience')
plt.legend()
plt.grid(True)
plt.show()
